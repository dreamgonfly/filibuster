# %%
from wordcloud import WordCloud

# %%
# %matplotlib inline

# %%
text = open('data/minutes_trimmed.txt').read()

# %%
wordcloud = WordCloud(font_path='/Users/libelo/Documents/YBIGTA/WeeklyDataScience/Filibuster/lib/Daum_SemiBold.ttf').generate(text)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from konlpy.tag import Kkma

# %%
kkma = Kkma()

# %%
kkma.nouns(text.split('\n')[2].strip())
# Out:
# ['오늘', '저', '테러', '테러방지법', '방지법', '관련', '무제한', '토론', '신청']

# %%
first_text = ' '.join(kkma.nouns(text))
# Out:
# ---------------------------------------------------------------------------
# java.lang.VirtualMachineErrorPyRaisable   Traceback (most recent call last)
# <ipython-input-45-630f5ed62e34> in <module>()
# ----> 1 first_text = ' '.join(kkma.nouns(text))
#
# /Users/libelo/anaconda/envs/Filibuster/lib/python3.5/site-packages/konlpy/tag/_kkma.py in nouns(self, phrase)
#      43         """Noun extractor."""
#      44
# ---> 45         nouns = self.jki.extractNoun(phrase)
#      46         if not nouns: return []
#      47         return [nouns.get(i).getString() for i in range(nouns.size())]
#
# java.lang.VirtualMachineErrorPyRaisable: java.lang.OutOfMemoryError: GC overhead limit exceeded

# %%
wordcloud = WordCloud(font_path='/Users/libelo/Documents/YBIGTA/WeeklyDataScience/Filibuster/lib/Daum_SemiBold.ttf').generate(first_text)

# %%
first_text
# Out:
# '김 김광진 광진 의원 사랑 존경 국민 분 국회 장님 선배 동료 오늘 저 테러 테러방지법 방지법 관련 무제한 토론 신청 정보 정보위원회의 위원 회의 법안 법안소위 소위 대한 대한민국 민국 누구 안보 반대 정치권 그것 민주 민주주의 주의 국가 공간 민의 반영 상임 상임위원회 위원회 논의 정보위원회 차례 중 과정 이후 법률 문제 제기 사실 19 19대 대 기간 단 때문 연계 그동안 생각 과 논 하자 것들 얘기 하나 국정원 가지 불신 지금 이 해소 여야 모두 일 정상적 국 국회의 운영 방식 초선 비례 비례대표 대표 4 4년 년 의정 의정활동 활동 자리 재선 3 3선 선 4선 그 선수 계신 여러분 상임위 절차 기본 수 데 합리적 평가 정의 정의화 화 의장 심사 심사기일 기일 1 1시 시 30 30분 분 처음 지정 직권 직권상정 상정 본회의 부의 박근 박근혜 혜 대통령 일방통행 불통 입법부 수장 국회의장 전달 국회법 천재지변 전시 사변 국가비상사태 비상사태 각 교섭 교섭단체 단체 합의 경우 심사기간 정 북한 핵 핵실험 실험 위험 증가 간주 대 근거 정황 첩보 우리 우리나라 나라 선포 사례 10 10월유신 월 유신 서막 종말 1971 1971년 12 12월 1979 1979년 10월 1980 1980년 5 5월 광주 광주민주화운동 민주화 운동 때 비상 비상계엄 계엄 확대 등 발생 우리 36 36년 만 헌법 77 77조 조 선언 계엄령 조치 헌정 사상 통상 방법 공공 안녕 입법 불가능 동의 기본권 자유 유린 시대 역사 시계추 전 논리 여섯 장거리 장거리미사일 미사일 발사 상황 상시 해당 전후 말 이 언제 정치 개입 극악 선례 날치기 강행 최악 사태 누리 누리당의 당의 예방 대응 제반 영장 통신 통신수단 수단 감청 무차별 정보수집 수집 물론 대테러활동 필요 자료 조사권 이 부분 마지막 최종적 협상 서도 과도 다라 지적 누리당 당 수정안 마련 요구 하나 변경 상태 무소 무소불위의 불 위의 무리수 추가 부여 괴물 의도 무엇 민주당 규탄 통과 행위 처사 번 파괴 심판 면 분 
# ...

# %%
[f for f in first_text.split(' ') if f == '우리']

# %%
plt.imshow(wordcloud)
plt.axis("off")
